# %%
# %%capture
from sys import path
path.insert(0, '../core')
from agyw import AgywPrev, AgywPrevCommune
from re import sub
from datetime import datetime
date_du_jour = datetime.today().strftime("%d_%m_%Y")
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from openpyxl import Workbook
from openpyxl.styles.colors import Color
from openpyxl.styles.fills import PatternFill
from openpyxl.styles import Font
from openpyxl.styles.alignment import Alignment
from openpyxl.utils.dataframe import dataframe_to_rows
from openpyxl.styles.borders import Border, Side

# %%
# %%capture
datim = AgywPrev()

# %%
datim.total_mastersheet
datim.total_dreams_valid
datim.total_datim_general
# Out:
# 6725
# 6525
# 6525

# %%
my_blue = Color(rgb="0000FF")
blue_fill = PatternFill(patternType="solid",fgColor=my_blue)
my_red = Color(rgb="FF0000")
red_fill = PatternFill(patternType="solid",fgColor=my_red)
bold_12 = Font(size=12,bold=True)

my_yellow = Color(rgb="FFC000")
yellow_fill= PatternFill(patternType="solid", fgColor=my_yellow)


text_datim_title = Alignment(horizontal="center",vertical="bottom",wrapText=True)

thin_border = Border(
    left=Side(style='thin'), 
    right=Side(style='thin'), 
    top=Side(style='thin'), 
    bottom=Side(style='thin')
)

the_width = 25
the_height = 50
special_h = 50

# %%
# %%capture
wb = Workbook()
ws = wb.active
ws.title = f"{datim.who_am_i}_Total"

#ws['A1'].fill = blue_fill
#ws['A10'].fill = blue_fill
#ws['A19'].fill = blue_fill
#ws['A28'].fill = blue_fill


ws.row_dimensions[1].height = the_height
ws.row_dimensions[10].height = the_height
ws.row_dimensions[19].height = the_height
ws.row_dimensions[28].height = the_height
ws.row_dimensions[37].height = special_h
ws.row_dimensions[38].height = special_h
ws.row_dimensions[39].height = special_h

ws.column_dimensions['A'].width = the_width
ws.column_dimensions['B'].width = the_width
ws.column_dimensions['C'].width = the_width
ws.column_dimensions['D'].width = the_width
ws.column_dimensions['E'].width = the_width
ws.column_dimensions['F'].width = the_width
ws.column_dimensions['I'].width = the_width

""" for rows in ws.iter_rows(min_row=8,max_row=8,min_col=1,max_col=40):
    for cell in rows:
        cell.fill = red_fill
for rows in ws.iter_rows(min_row=9,max_row=9,min_col=1,max_col=40):
    for cell in rows:
        cell.fill = red_fill
for rows in ws.iter_rows(min_row=17,max_row=17,min_col=1,max_col=40):
    for cell in rows:
        cell.fill = red_fill
for rows in ws.iter_rows(min_row=18,max_row=18,min_col=1,max_col=40):
    for cell in rows:
        cell.fill = red_fill
for rows in ws.iter_rows(min_row=26,max_row=26,min_col=1,max_col=40):
    for cell in rows:
        cell.fill = red_fill
for rows in ws.iter_rows(min_row=27,max_row=27,min_col=1,max_col=40):
    for cell in rows:
        cell.fill = red_fill
for rows in ws.iter_rows(min_row=35,max_row=35,min_col=1,max_col=40):
    for cell in rows:
        cell.fill = red_fill
for rows in ws.iter_rows(min_row=36,max_row=36,min_col=1,max_col=40):
    for cell in rows:
        cell.fill = red_fill """
        

ws.cell(row=37,column=1).font = bold_12
ws.cell(row=37,column=1).alignment =  text_datim_title
ws.cell(row=38,column=1).font = bold_12
ws.cell(row=38,column=1).alignment =  text_datim_title
ws.cell(row=39,column=1).font = bold_12
ws.cell(row=39,column=1).alignment =  text_datim_title            
ws.merge_cells("A37:D37")
ws.merge_cells("A38:D38")
ws.merge_cells("A39:D39")

ws.merge_cells("A1:E1")
ws.cell(row=1,column=1).value = AgywPrev.datim_titleII()
ws.cell(row=1,column=1).font = bold_12
ws.cell(row=1,column=1).alignment =  text_datim_title
ws.cell(row=1,column=1).fill =  yellow_fill

ws.merge_cells("A10:E10")
ws.cell(row=10,column=1).value = AgywPrev.datim_titleI()
ws.cell(row=10,column=1).font = bold_12
ws.cell(row=10,column=1).alignment =  text_datim_title
ws.cell(row=10,column=1).fill =  yellow_fill

ws.merge_cells("A19:E19")
ws.cell(row=19,column=1).value = AgywPrev.datim_titleIII()
ws.cell(row=19,column=1).font = bold_12
ws.cell(row=19,column=1).alignment =  text_datim_title
ws.cell(row=19,column=1).fill =  yellow_fill

ws.merge_cells("A28:E28")
ws.cell(row=28,column=1).value = AgywPrev.datim_titleIV()
ws.cell(row=28,column=1).font = bold_12
ws.cell(row=28,column=1).alignment =  text_datim_title
ws.cell(row=28,column=1).fill =  yellow_fill

ws['F7'] = datim.total_datimII
ws['F16'] = datim.total_datimI
ws['F25'] = datim.total_datimIII
ws['F34'] = datim.total_datimIV
ws['I13'] = datim.total_datim_general

rdf_datim_II = dataframe_to_rows(datim.datim_agyw_prevII(),index=False,header=True)
for ridx, row in enumerate(rdf_datim_II,1):
    for cidx, value in enumerate(row,1):
        cells = ws.cell(ridx+1,cidx,value)
        cells.border = thin_border
        cells

rdf_datim_I = dataframe_to_rows(datim.datim_agyw_prevI(),index=False,header=True)
for ridx, row in enumerate(rdf_datim_I,1):
    for cidx, value in enumerate(row,1):
        cells = ws.cell(ridx+10,cidx,value)
        cells.border = thin_border
        cells

rdf_datim_III = dataframe_to_rows(datim.datim_agyw_prevIII(),index=False,header=True)
for ridx, row in enumerate(rdf_datim_III,1):
    for cidx, value in enumerate(row,1):
        cells = ws.cell(ridx+19,cidx,value)
        cells.border = thin_border
        cells

rdf_datim_IV = dataframe_to_rows(datim.datim_agyw_prevIV(),index=False,header=True)
for ridx, row in enumerate(rdf_datim_IV,1):
    for cidx, value in enumerate(row,1):
        cells = ws.cell(ridx+28,cidx,value)
        cells.border = thin_border
        cells

# %%
special_scenario = {}
rdf_datim_info = dataframe_to_rows(datim.datim_vital_info(),index=False,header=True)
for ridx, row in enumerate(rdf_datim_info):
    special_scenario[ridx] =  [value for i,value in enumerate(row)]



ws.cell(37,1,special_scenario[0][0]).border = thin_border
ws.cell(38,1,special_scenario[1][0]).border = thin_border
ws.cell(39,1,special_scenario[2][0]).border = thin_border
ws.cell(37,5,special_scenario[0][1]).border = thin_border
ws.cell(38,5,special_scenario[1][1]).border = thin_border
ws.cell(39,5,special_scenario[2][1]).border = thin_border

ws.cell(37,2).border = thin_border
ws.cell(38,2).border = thin_border
ws.cell(39,2).border = thin_border
ws.cell(37,3).border = thin_border
ws.cell(38,3).border = thin_border
ws.cell(39,3).border = thin_border
ws.cell(37,4).border = thin_border
ws.cell(38,4).border = thin_border
ws.cell(39,4).border = thin_border

# %%
special_scenario
# Out:
# {0: ['Number of active DREAMS participants that received an evidence-based intervention focused on preventing violence within the reporting period.',
#   6034],
#  1: ['Number of active DREAMS participants that received educational support to remain in, advance, and/or rematriculate in school within the reporting period.',
#   366],
#  2: ['Number of active DREAMS participants that completed a comprehensive economic strengthening intervention within the past 6 months at Q2 or past 12 months at Q4.',
#   968]}

# %%
#wb.sheetnames

def name_handler(s):
    s = sub(r"[^\w\s]", '', s)
    # Replace all runs of whitespace with a single dash
    s = sub(r"\s+", '_', s)
    return s

# %%
# %%capture
worksheets = []
datimcommunes = []
cols  = datim.data_mastersheet.commune.unique()
columns = [i for i in cols if i is not None]
for columns in columns:
    globals()[f"ws_{name_handler(columns)}"] = wb.create_sheet(title=AgywPrevCommune(f"{columns}").who_am_i)
    globals()[f"datim_{name_handler(columns)}"] =AgywPrevCommune(f"{columns}")
    worksheets.append(globals().get(f"ws_{name_handler(columns)}"))
    datimcommunes.append(globals().get(f"datim_{name_handler(columns)}"))

# %%
# %%capture
worksheets
datimcommunes

# %%
# %%capture
for wscommunes, dcommunes in zip(worksheets,datimcommunes):
    #wscommunes['A1'].fill = blue_fill
    #wscommunes['A10'].fill = blue_fill
    #wscommunes['A19'].fill = blue_fill
    #wscommunes['A28'].fill = blue_fill
    
    wscommunes.row_dimensions[1].height = the_height
    wscommunes.row_dimensions[10].height = the_height
    wscommunes.row_dimensions[19].height = the_height
    wscommunes.row_dimensions[28].height = the_height
    #wscommunes.row_dimensions[37].height = special_h
    #wscommunes.row_dimensions[38].height = special_h
    #wscommunes.row_dimensions[39].height = special_h
    wscommunes.row_dimensions[37].height = the_height
    wscommunes.row_dimensions[38].height = the_height
    wscommunes.row_dimensions[39].height = the_height

    
    wscommunes.column_dimensions['A'].width = the_width
    wscommunes.column_dimensions['B'].width = the_width
    wscommunes.column_dimensions['C'].width = the_width
    wscommunes.column_dimensions['D'].width = the_width
    wscommunes.column_dimensions['E'].width = the_width
    wscommunes.column_dimensions['F'].width = the_width
    wscommunes.column_dimensions['I'].width = the_width

    """ for rows in wscommunes.iter_rows(min_row=8,max_row=8,min_col=1,max_col=40):
            for cell in rows:
                cell.fill = red_fill
        for rows in wscommunes.iter_rows(min_row=9,max_row=9,min_col=1,max_col=40):
            for cell in rows:
                cell.fill = red_fill
        for rows in wscommunes.iter_rows(min_row=17,max_row=17,min_col=1,max_col=40):
            for cell in rows:
                cell.fill = red_fill
        for rows in wscommunes.iter_rows(min_row=18,max_row=18,min_col=1,max_col=40):
            for cell in rows:
                cell.fill = red_fill
        for rows in wscommunes.iter_rows(min_row=26,max_row=26,min_col=1,max_col=40):
            for cell in rows:
                cell.fill = red_fill
        for rows in wscommunes.iter_rows(min_row=27,max_row=27,min_col=1,max_col=40):
            for cell in rows:
                cell.fill = red_fill
        for rows in wscommunes.iter_rows(min_row=35,max_row=35,min_col=1,max_col=40):
            for cell in rows:
                cell.fill = red_fill
        for rows in wscommunes.iter_rows(min_row=36,max_row=36,min_col=1,max_col=40):
            for cell in rows:
                cell.fill = red_fill """
                
    wscommunes.cell(row=37,column=1).font = bold_12
    wscommunes.cell(row=37,column=1).alignment =  text_datim_title
    wscommunes.cell(row=38,column=1).font = bold_12
    wscommunes.cell(row=38,column=1).alignment =  text_datim_title
    wscommunes.cell(row=39,column=1).font = bold_12
    wscommunes.cell(row=39,column=1).alignment =  text_datim_title            
    wscommunes.merge_cells("A37:D37")
    wscommunes.merge_cells("A38:D38")
    wscommunes.merge_cells("A39:D39")
    
        
    wscommunes.merge_cells("A1:E1")
    wscommunes.cell(row=1,column=1).value = AgywPrevCommune.datim_titleII()
    wscommunes.cell(row=1,column=1).font = bold_12
    wscommunes.cell(row=1,column=1).alignment =  text_datim_title
    wscommunes.cell(row=1,column=1).fill =  yellow_fill

    wscommunes.merge_cells("A10:E10")
    wscommunes.cell(row=10,column=1).value = AgywPrevCommune.datim_titleI()
    wscommunes.cell(row=10,column=1).font = bold_12
    wscommunes.cell(row=10,column=1).alignment =  text_datim_title
    wscommunes.cell(row=10,column=1).fill =  yellow_fill

    wscommunes.merge_cells("A19:E19")
    wscommunes.cell(row=19,column=1).value = AgywPrevCommune.datim_titleIII()
    wscommunes.cell(row=19,column=1).font = bold_12
    wscommunes.cell(row=19,column=1).alignment =  text_datim_title
    wscommunes.cell(row=19,column=1).fill =  yellow_fill

    wscommunes.merge_cells("A28:E28")
    wscommunes.cell(row=28,column=1).value = AgywPrevCommune.datim_titleIV()
    wscommunes.cell(row=28,column=1).font = bold_12
    wscommunes.cell(row=28,column=1).alignment =  text_datim_title
    wscommunes.cell(row=28,column=1).fill =  yellow_fill

    wscommunes['F7'] = dcommunes.total_datimII
    wscommunes['F16'] = dcommunes.total_datimI
    wscommunes['F25'] = dcommunes.total_datimIII
    wscommunes['F34'] = dcommunes.total_datimIV
    wscommunes['I13'] = dcommunes.total_datim_general
    
    
    for ridx, row in enumerate(dataframe_to_rows(dcommunes.datim_agyw_prevII(),index=False,header=True),1):
        for cidx, value in enumerate(row,1):
            cells = wscommunes.cell(ridx+1,cidx,value)
            cells.border = thin_border
            cells

    for ridx, row in enumerate(dataframe_to_rows(dcommunes.datim_agyw_prevI(),index=False,header=True),1):
        for cidx, value in enumerate(row,1):
            cells = wscommunes.cell(ridx+10,cidx,value)
            cells.border = thin_border
            cells

    for ridx, row in enumerate(dataframe_to_rows(dcommunes.datim_agyw_prevIII(),index=False,header=True),1):
        for cidx, value in enumerate(row,1):
            cells = wscommunes.cell(ridx+19,cidx,value)
            cells.border = thin_border
            cells
    
    for ridx, row in enumerate(dataframe_to_rows(dcommunes.datim_agyw_prevIV(),index=False,header=True),1):
        for cidx, value in enumerate(row,1):
            cells = wscommunes.cell(ridx+28,cidx,value)
            cells.border = thin_border
            cells
    #for ridx, row in enumerate(dataframe_to_rows(dcommunes.datim_vital_info(),index=False,header=True),1):
    #    for cidx, value in enumerate(row,1):
            #cells = wscommunes.cell(ridx+37,cidx,value)
            #cells.border = thin_border
            #cells
    special_scenario_communes = {}
    for ridx, row in enumerate(dataframe_to_rows(dcommunes.datim_vital_info(),index=False,header=True)):
        special_scenario_communes[ridx] =  [value for i,value in enumerate(row)]
    wscommunes.cell(37,1,special_scenario_communes[0][0]).border = thin_border
    wscommunes.cell(38,1,special_scenario_communes[1][0]).border = thin_border
    wscommunes.cell(39,1,special_scenario_communes[2][0]).border = thin_border
    wscommunes.cell(37,5,special_scenario_communes[0][1]).border = thin_border
    wscommunes.cell(38,5,special_scenario_communes[1][1]).border = thin_border
    wscommunes.cell(39,5,special_scenario_communes[2][1]).border = thin_border
    special_scenario_communes.clear()
    
    wscommunes.cell(37,2).border = thin_border
    wscommunes.cell(38,2).border = thin_border
    wscommunes.cell(39,2).border = thin_border
    wscommunes.cell(37,3).border = thin_border
    wscommunes.cell(38,3).border = thin_border
    wscommunes.cell(39,3).border = thin_border
    wscommunes.cell(37,4).border = thin_border
    wscommunes.cell(38,4).border = thin_border
    wscommunes.cell(39,4).border = thin_border

# %%
wb.save(f"./datim_results/AGYWPREV.xlsx")
#wb.save(f"./datim_results/AGYWPREV_{date_du_jour}.xlsx")
#wb.save(f"./datim_results/ONFY21/AGYWPREV_{date_du_jour}.xlsx")
#wb.save(f"./datim_results/special/AGYWPREV_{date_du_jour}.xlsx")
#wb.save(f"./datim_results/Q3/AGYWPREV_{date_du_jour}.xlsx")
