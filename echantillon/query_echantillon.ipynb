# %%
# %%capture

from pandas import ExcelWriter
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"


from staticV22.agyw import AgywPrev

# %% [markdown]
# # 3 eme et 4eme semaine de novembre!

# %%
# %%capture
datim = AgywPrev()

# %%
datim.data_dreams_valid
datim.total_datim_general
df = datim.data_dreams_valid
# Out:
#        id_patient  id_parenting_group departement      commune  \
# 226         75394              3363.0        Nord        Milot
# 227         75395                 NaN        Nord        Milot
# 244         75528                 NaN        Nord  Cap-Haïtien
# 275         75987                 NaN  Artibonite   Dessalines
# 287         75964                 NaN  Artibonite    Liancourt
# ...           ...                 ...         ...          ...
# 35198      100543                 NaN        Nord  Cap-Haïtien
# 35199      101428                 NaN        Nord        Milot
# 35200      105142                 NaN        Nord  Cap-Haïtien
# 35201      105158                 NaN        Nord  Cap-Haïtien
# 35202      105341                 NaN        Nord  Cap-Haïtien
#
#        nbre_pres_for_inter  nbre_parenting_coupe_present has_comdom_topic  \
# 226                     21                            10              yes
# 227                     21                             0              yes
# 244                     17                             0              yes
# 275                     17                             0              yes
# 287                     17                             0              yes
# ...                    ...                           ...              ...
# 35198                    0                             0               no
# 35199                    0                             0               no
# 35200                    0                             0               no
# 35201                    0                             0               no
# 35202                    0                             0               no
#
#       has_preventive_vbg  number_of_condoms_sensibilize  \
# 226                  yes                              0
# 227                  yes                              0
# 244                  yes                              1
# 275                  yes                              1
# 287                  yes                              0
# ...                  ...                            ...
# 35198               None                              0
# 35199               None                              0
# 35200               None                              0
# 35201               None                              0
# 35202               None                              0
#
#        number_condoms_sensibilization_date_in_the_interval  ...  socioeco_app  \
# 226                                                    0    ...           yes
# 227                                                    0    ...           yes
# 244                                                    0    ...           yes
# 275                                                    0    ...           yes
# 287                                                    0    ...           yes
# ...                                                  ...    ...           ...
# 35198                                                  0    ...           yes
# 35199                                                  0    ...           yes
# 35200                                                  0    ...           yes
# 35201                                                  0    ...           yes
# 35202                                                  0    ...           yes
#
#        prep contraceptive  ps_1014  ps_1519  ps_2024  primary_only  \
# 226      no            no       no  primary       no       invalid
# 227      no            no       no  primary       no       invalid
# 244      no            no       no  primary       no       invalid
# 275      no            no       no  primary       no       invalid
# 287      no            no       no       no  primary       invalid
# ...     ...           ...      ...      ...      ...           ...
# 35198    no            no       no       no       no       invalid
# 35199    no            no       no       no       no       invalid
# 35200    no            no       no       no       no       invalid
# 35201    no            no       no       no       no       invalid
# 35202    no            no       no       no       no       invalid
#
#        primary_and_OneSecondary_services  completed_one_service  \
# 226       full_primary_leastOneSecondary                invalid
# 227       full_primary_leastOneSecondary                invalid
# 244       full_primary_leastOneSecondary                invalid
# 275       full_primary_leastOneSecondary                invalid
# 287       full_primary_leastOneSecondary                invalid
# ...                                  ...                    ...
# 35198                            invalid  primary_part_services
# 35199                            invalid  primary_part_services
# 35200                            invalid  primary_part_services
# 35201                            invalid  primary_part_services
# 35202                            invalid  primary_part_services
#
#       has_started_one_service
# 226                        no
# 227                        no
# 244                        no
# 275                        no
# 287                        no
# ...                       ...
# 35198                      no
# 35199                      no
# 35200                      no
# 35201                      no
# 35202                      no
#
# [1796 rows x 44 columns]
# 1796

# %%
df_sample  = df.sample(frac=0.1,random_state=1)
df_sample
# Out:
#        id_patient  id_parenting_group departement      commune  \
# 32721      128979                 NaN  Artibonite   Saint-Marc
# 7232        83087                 NaN  Artibonite  La Chapelle
# 33487      130041                 NaN       Ouest      Tabarre
# 32750      129083                 NaN       Ouest       Delmas
# 9539       131544                 NaN       Ouest      Tabarre
# ...           ...                 ...         ...          ...
# 8368        80137                 NaN  Artibonite    Verrettes
# 14163       81805                 NaN  Artibonite     Desdunes
# 33850      130564                 NaN        Nord  Cap-Haïtien
# 32739      129036                 NaN       Ouest  Pétionville
# 2677        79322                 NaN  Artibonite    Verrettes
#
#        nbre_pres_for_inter  nbre_parenting_coupe_present has_comdom_topic  \
# 32721                   18                             0              yes
# 7232                    21                             0              yes
# 33487                   21                             0              yes
# 32750                   21                             0              yes
# 9539                    21                             0              yes
# ...                    ...                           ...              ...
# 8368                    17                             0              yes
# 14163                   18                             0              yes
# 33850                   18                             0              yes
# 32739                   21                             0              yes
# 2677                    17                             0              yes
#
#       has_preventive_vbg  number_of_condoms_sensibilize  \
# 32721                yes                              0
# 7232                 yes                              0
# 33487                yes                              0
# 32750                yes                              0
# 9539                 yes                              1
# ...                  ...                            ...
# 8368                 yes                              1
# 14163                yes                              0
# 33850                yes                              0
# 32739                yes                              0
# 2677                 yes                              0
#
#        number_condoms_sensibilization_date_in_the_interval  ...  socioeco_app  \
# 32721                                                  0    ...            no
# 7232                                                   0    ...            no
# 33487                                                  0    ...            no
# 32750                                                  0    ...            no
# 9539                                                   1    ...            no
# ...                                                  ...    ...           ...
# 8368                                                   1    ...           yes
# 14163                                                  0    ...           yes
# 33850                                                  0    ...            no
# 32739                                                  0    ...            no
# 2677                                                   0    ...           yes
#
#        prep contraceptive  ps_1014  ps_1519  ps_2024       primary_only  \
# 32721    no            no  primary       no       no            invalid
# 7232    yes            no       no  primary       no            invalid
# 33487    no            no  primary       no       no            invalid
# 32750    no            no       no       no  primary  full_primary_only
# 9539     no            no  primary       no       no            invalid
# ...     ...           ...      ...      ...      ...                ...
# 8368     no            no       no       no  primary            invalid
# 14163    no            no  primary       no       no            invalid
# 33850    no            no       no  primary       no  full_primary_only
# 32739    no            no  primary       no       no            invalid
# 2677     no            no       no  primary       no            invalid
#
#        primary_and_OneSecondary_services completed_one_service  \
# 32721     full_primary_leastOneSecondary               invalid
# 7232      full_primary_leastOneSecondary               invalid
# 33487     full_primary_leastOneSecondary               invalid
# 32750                            invalid               invalid
# 9539      full_primary_leastOneSecondary               invalid
# ...                                  ...                   ...
# 8368      full_primary_leastOneSecondary               invalid
# 14163     full_primary_leastOneSecondary               invalid
# 33850                            invalid               invalid
# 32739     full_primary_leastOneSecondary               invalid
# 2677      full_primary_leastOneSecondary               invalid
#
#       has_started_one_service
# 32721                      no
# 7232                       no
# 33487                      no
# 32750                      no
# 9539                       no
# ...                       ...
# 8368                       no
# 14163                      no
# 33850                      no
# 32739                      no
# 2677                       no
#
# [180 rows x 44 columns]

# %%
resume_sample = df_sample.pivot_table(values="id_patient",index='age_range',columns='departement',aggfunc='count',fill_value=0,margins=True,margins_name="Total")
resume_sample
# Out:
# departement  Artibonite  Nord  Ouest  Total
# age_range
# 10-14                34     9     31     74
# 15-19                43    11     18     72
# 20-24                20     6      8     34
# Total                97    26     57    180

# %%
artibonites = df_sample[df_sample.departement == "Artibonite"]
nord = df_sample[df_sample.departement == "Nord"]
ouest = df_sample[df_sample.departement == "Ouest"]

artibonites.id_patient.count()
nord.id_patient.count()
ouest.id_patient.count()
# Out:
# 97
# 26
# 57

# %%
sampling = ExcelWriter("echantillon_Q1FY22.xlsx",engine="xlsxwriter")
resume_sample.to_excel(sampling,sheet_name="Tableau Resume", index=True)
artibonites.to_excel(sampling,sheet_name="Artibonite", index=False, na_rep="")
nord.to_excel(sampling,sheet_name="Nord", index=False, na_rep="")
ouest.to_excel(sampling,sheet_name="Ouest", index=False, na_rep="")
sampling.save()
