# %%
# %%capture
from sys import path
path.insert(0, '../static')
from agyw import AgywPrev
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from pandas import DataFrame

# %%
# %%capture
datim = AgywPrev()

# %% [markdown]
# # base active

# %%
base = datim.data_dreams_valid
base.id_patient.count()
# Out:
# 19229

# %% [markdown]
# # Curriculum

# %%
curriculum_complet = base[
    (base.curriculum=="yes")
]
curriculum_complet.id_patient.count()

curriculum_table = curriculum_complet.pivot_table(index="age_range",columns="curriculum",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
curriculum_table
# Out:
# 16746
# curriculum     yes  Grand Total
# age_range
# 10-14         5822         5822
# 15-19         6991         6991
# 20-24         3933         3933
# Grand Total  16746        16746

# %% [markdown]
# # least one curriculum

# %%
curriculum_least = base[
    (base.curriculum_detailed!="no")
]
curriculum_least.id_patient.count()

curriculum_table = curriculum_least.pivot_table(index="age_range",columns="curriculum_detailed",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
curriculum_table
# Out:
# 18999
# curriculum_detailed  has_started    yes  Grand Total
# age_range
# 10-14                        949   5822         6771
# 15-19                        906   6991         7897
# 20-24                        398   3933         4331
# Grand Total                 2253  16746        18999

# %% [markdown]
# # Parenting

# %%
parenting = base[
    (base.parenting=="yes")
]
parenting.id_patient.count()
parenting_table = parenting.pivot_table(index="age_range",columns="parenting",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
parenting_table
# Out:
# 321
# parenting    yes  Grand Total
# age_range
# 10-14        165          165
# 15-19        156          156
# Grand Total  321          321

# %% [markdown]
# # least one session parenting

# %%
parenting_leastone= base[
    (base.parenting_detailed!="no")
]

parenting_leastone.id_patient.count()
parenting_table = parenting_leastone.pivot_table(index="age_range",columns="parenting_detailed",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
parenting_table


# ---------------

parenting_started = base[
    (base.parenting_detailed=='has_started')
]
parenting_started.id_patient.count()
# Out:
# 422
# parenting_detailed  has_started  yes  Grand Total
# age_range
# 10-14                        49  165          214
# 15-19                        52  156          208
# Grand Total                 101  321          422
# 101

# %% [markdown]
# # condoms

# %%
condom = base[
    (base.condom=="yes")
]
condom.id_patient.count()

condom_table = condom.pivot_table(index="age_range",columns="condom",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
condom_table
# Out:
# 18846
# condom         yes  Grand Total
# age_range
# 10-14         6612         6612
# 15-19         7872         7872
# 20-24         4362         4362
# Grand Total  18846        18846

# %% [markdown]
# # HTS

# %%
hts = base[
    (base.hts=="yes")
]
hts.id_patient.count()

hts_table = hts.pivot_table(index="age_range",columns="hts",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
hts_table
# Out:
# 2885
# hts           yes  Grand Total
# age_range
# 10-14         441          441
# 15-19        1186         1186
# 20-24        1258         1258
# Grand Total  2885         2885

# %% [markdown]
# # post violence care

# %%
post_violence_care = base[
    (base.post_violence_care=="yes")
]
post_violence_care.id_patient.count()

post_violence_care_table = post_violence_care.pivot_table(index="age_range",columns="post_violence_care",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
post_violence_care_table
# Out:
# 201
# post_violence_care  yes  Grand Total
# age_range
# 10-14                19           19
# 15-19                84           84
# 20-24                98           98
# Grand Total         201          201

# %%
vbg = base[
    (base.vbg=="yes")
]
vbg.id_patient.count()

vbg_table = vbg.pivot_table(index="age_range",columns="vbg",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
vbg_table
# Out:
# 68
# vbg          yes  Grand Total
# age_range
# 10-14          2            2
# 15-19         26           26
# 20-24         40           40
# Grand Total   68           68

# %%
gyneco = base[
    (base.gyneco=="yes")
]
gyneco.id_patient.count()

gyneco_table = gyneco.pivot_table(index="age_range",columns="gyneco",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
gyneco_table
# Out:
# 158
# gyneco       yes  Grand Total
# age_range
# 10-14         17           17
# 15-19         66           66
# 20-24         75           75
# Grand Total  158          158

# %% [markdown]
# # Socio_eco_app

# %%
socioeco_app = base[
    (base.socioeco_app=="yes")
]
socioeco_app.id_patient.count()

socioeco_app_table = socioeco_app.pivot_table(index="age_range",columns="socioeco_app",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
socioeco_app_table
# Out:
# 645
# socioeco_app  yes  Grand Total
# age_range
# 10-14         180          180
# 15-19         228          228
# 20-24         237          237
# Grand Total   645          645

# %% [markdown]
# # Prep

# %%
prep = base[
    (base.prep=="yes")
]
prep.id_patient.count()

prep_table = prep.pivot_table(index="age_range",columns="prep",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
prep_table


#GOOD!!!!!
# Out:
# 226
# prep         yes  Grand Total
# age_range
# 15-19        103          103
# 20-24        123          123
# Grand Total  226          226

# %% [markdown]
# # Contraceptive

# %%
contraceptive = base[
    (base.contraceptive=="yes")
]
contraceptive.id_patient.count()
if contraceptive.id_patient.count() !=0:
    contraceptive_table = contraceptive.pivot_table(index="age_range",columns="contraceptive",
                            values='id_patient',
                            aggfunc='count',
                            fill_value=0,
                            margins=True,
                            margins_name="Grand Total"                             
    )
    contraceptive_table
# Out:
# 15
# contraceptive  yes  Grand Total
# age_range
# 15-19            3            3
# 20-24           12           12
# Grand Total     15           15

# %% [markdown]
# # Primary_services

# %%
ps_1014 = base[
    (base.ps_1014=="primary")
]
ps_1014.id_patient.count()

ps_1014_table = ps_1014.pivot_table(index="age_range",columns="ps_1014",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
ps_1014_table
# Out:
# 5822
# ps_1014      primary  Grand Total
# age_range
# 10-14           5822         5822
# Grand Total     5822         5822

# %%
ps_1519 = base[
    (base.ps_1519=="primary")
]
ps_1519.id_patient.count()

ps_1519_table = ps_1519.pivot_table(index="age_range",columns="ps_1519",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
ps_1519_table
# Out:
# 6991
# ps_1519      primary  Grand Total
# age_range
# 15-19           6991         6991
# Grand Total     6991         6991

# %%
ps_2024 = base[
    (base.ps_2024=="primary")
]
ps_2024.id_patient.count()

ps_2024_table = ps_2024.pivot_table(index="age_range",columns="ps_2024",
                        values='id_patient',
                        aggfunc='count',
                        fill_value=0,
                        margins=True,
                        margins_name="Grand Total"                             
)
ps_2024_table
# Out:
# 3933
# ps_2024      primary  Grand Total
# age_range
# 20-24           3933         3933
# Grand Total     3933         3933

# %% [markdown]
# # find scenarios

# %%
resum_parenting =DataFrame.from_dict(parenting_leastone.commune.value_counts().to_dict(),orient='index',columns=['nombre_de_beneficiaires'])
resum_parenting.to_excel('./parenting_repartition_beneficiaires/repartition_parenting_par_commune.xlsx',index=True,na_rep="")
hts.to_excel('./hivTested/hivTestedBeneficiairies.xlsx',index=False,na_rep="")
parenting.to_excel('./parenting_repartition_beneficiaires/parenting_completed.xlsx',na_rep="",index=False)
parenting_started.to_excel('./parenting_repartition_beneficiaires/parenting_has_started.xlsx',na_rep="",index=False)

# %%
curriculum_complet[(curriculum_complet.nbre_pres_for_inter==14) | (curriculum_complet.nbre_pres_for_inter==16)]
# Out:
#        id_patient  id_parenting_group departement     commune  \
# 272         75975                 NaN       Ouest    Kenscoff
# 311         76263                 NaN       Ouest    Kenscoff
# 404         76990                 NaN       Ouest    Kenscoff
# 413         77152                 NaN  Artibonite   Liancourt
# 598         79109                 NaN       Ouest   Carrefour
# ...           ...                 ...         ...         ...
# 31738      127452                 NaN  Artibonite  Saint-Marc
# 31739      127453                 NaN  Artibonite  Saint-Marc
# 31740      127454                 NaN  Artibonite  Saint-Marc
# 31741      127455                 NaN  Artibonite  Saint-Marc
# 31742      127456                 NaN  Artibonite  Saint-Marc
#
#        nbre_pres_for_inter  nbre_parenting_coupe_present has_comdom_topic  \
# 272                     16                             0              yes
# 311                     16                             0              yes
# 404                     16                             0              yes
# 413                     16                             0              yes
# 598                     16                             0              yes
# ...                    ...                           ...              ...
# 31738                   14                             0              yes
# 31739                   14                             0              yes
# 31740                   14                             0              yes
# 31741                   14                             0              yes
# 31742                   14                             0              yes
#
#        number_of_condoms_sensibilize  \
# 272                                5
# 311                                2
# 404                                1
# 413                                0
# 598                                0
# ...                              ...
# 31738                              0
# 31739                              0
# 31740                              0
# 31741                              0
# 31742                              0
#
#        number_condoms_sensibilization_date_in_the_interval  \
# 272                                                    0
# 311                                                    0
# 404                                                    0
# 413                                                    0
# 598                                                    0
# ...                                                  ...
# 31738                                                  0
# 31739                                                  0
# 31740                                                  0
# 31741                                                  0
# 31742                                                  0
#
#        number_condoms_reception_in_the_interval  ...  socioeco_app  prep  \
# 272                                           5  ...            no    no
# 311                                           2  ...            no    no
# 404                                           2  ...            no    no
# 413                                           1  ...           yes    no
# 598                                           0  ...            no    no
# ...                                         ...  ...           ...   ...
# 31738                                         0  ...            no    no
# 31739                                         0  ...            no    no
# 31740                                         0  ...            no    no
# 31741                                         0  ...            no    no
# 31742                                         0  ...            no    no
#
#        contraceptive  ps_1014  ps_1519  ps_2024       primary_only  \
# 272               no       no  primary       no            invalid
# 311               no  primary       no       no            invalid
# 404               no       no       no  primary            invalid
# 413               no       no       no  primary            invalid
# 598               no       no       no  primary            invalid
# ...              ...      ...      ...      ...                ...
# 31738             no       no  primary       no  full_primary_only
# 31739             no  primary       no       no            invalid
# 31740             no       no  primary       no  full_primary_only
# 31741             no       no  primary       no  full_primary_only
# 31742             no       no       no  primary  full_primary_only
#
#       primary_and_OneSecondary_services completed_one_service  \
# 272      full_primary_leastOneSecondary               invalid
# 311      full_primary_leastOneSecondary               invalid
# 404      full_primary_leastOneSecondary               invalid
# 413      full_primary_leastOneSecondary               invalid
# 598      full_primary_leastOneSecondary               invalid
# ...                                 ...                   ...
# 31738                           invalid               invalid
# 31739    full_primary_leastOneSecondary               invalid
# 31740                           invalid               invalid
# 31741                           invalid               invalid
# 31742                           invalid               invalid
#
#       has_started_one_service
# 272                        no
# 311                        no
# 404                        no
# 413                        no
# 598                        no
# ...                       ...
# 31738                      no
# 31739                      no
# 31740                      no
# 31741                      no
# 31742                      no
#
# [1353 rows x 42 columns]
